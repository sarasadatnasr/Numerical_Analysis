# %% [markdown]
# # differential Equation
# sarasadat nasr  99222109

# %% [markdown]
# # introduction
# goal : calculate the temperature of each point of shaft
#
# equation : y''(x)+xy'(x)+y(x) = $\sqrt{1+x}$

# %% [markdown]
# import requirements

# %%
from math import sqrt, exp, cos, sin
import matplotlib.pyplot as plt


def secondOrderDifferential(x0, xn, y0, z0, h):
    n = int((xn - x0)/h)
    # Containers for solutions
    xlist = [0] * (n + 1)
    ylist = [0] * (n + 1)
    zlist = [0] * (n + 1)

    xlist[0] = x = x0
    ylist[0] = y = y0
    zlist[0] = z = z0

    for i in range(1, n + 1):
        # see https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods
        k1 = h * f(x, y, z)
        l1 = h * g(x, y, z)
        k2 = h * f(x + 0.5 * h, y + 0.5 * k1, z + 0.5*l1)
        l2 = h * g(x + 0.5 * h, y + 0.5 * k1, z + 0.5*l1)
        k3 = h * f(x + 0.5 * h, y + 0.5 * k2, z + 0.5*l2)
        l3 = h * g(x + 0.5 * h, y + 0.5 * k2, z + 0.5*l2)
        k4 = h * f(x + h, y + k2, z + l2)
        l4 = h * g(x + h, y + k2, z + l2)
        xlist[i] = x = x0 + i * h
        ylist[i] = y = y + (k1 + 2*k2 + 2*k3 + k4) / 6
        zlist[i] = z = z + (l1 + 2*l2 + 2*l3 + l4) / 6

    return xlist, ylist


def g(x, y, z):
    # z' = 4y
    return 4*y


def f(x, y, z):
    # y' = z
    return z


def exact(x):
    # analytical solution y = exp(2*x)
    return exp(2*x)


def plot(x1, y1, x2, y2, color1, color2, linestyle1, linestyle2, h):
    dpi = 80
    fig = plt.figure(dpi=dpi, figsize=(1600 / dpi, 900 / dpi))

    plt.plot(x1, y1, color=color1, linestyle=linestyle1,
             label='Numerical Solution')
    plt.plot(x2, y2, color=color2, linestyle=linestyle2,
             label='Analytical Solution')
    equation = "y'' - xy' + y = 1+x"
    name = "second order differential equation"
    title = '%s, h = %s, The second order differential equation method by %s, %s' %(equation, h, name)
    plt.title(title, fontsize=20)
    plt.xlabel('x', fontsize=20)
    plt.ylabel('y', fontsize=20)
    plt.legend(loc='upper right')
    plt.show()
 
    # Uncomment the following to print the figure:
    #file_name = str(h1) + '_2_RungeKutta4.png'
    #fig.savefig(file_name)

# %%
if __name__ == '__main__':
    # set initial conditions y(x0) = y0, z(x0) = z0 and other parametrs
    # xn is the final point
    # h1 > 0 is step-size for Numerical Solution
    # h2 > 0 is step-size for Analytical Solution
    x0 = 0
    xn = 1
    h1 = 0.25
    h2 = 0.05
    y0 = 20
    z0 = 25

    xlist1, ylist1 = secondOrderDifferential(x0, xn, y0, z0, h1)

    xlist2 = [x*h2 for x in range(x0, int(xn/h2+1))]
    ylist2 = [exact(x) for x in xlist2]

    plot(xlist1, ylist1, xlist2, ylist2, 'blue', 'red', 'solid', 'solid', h1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/sarasadatnasr/Desktop/Spam/pythonFile/numerical_Analysis/HW_3_2.ipynb Cell 5 in <cell line: 1>()
#      <a href='vscode-notebook-cell:/home/sarasadatnasr/Desktop/Spam/pythonFile/numerical_Analysis/HW_3_2.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> xlist2 = [x*h2 for x in range(x0, int(xn/h2+1))]
#      <a href='vscode-notebook-cell:/home/sarasadatnasr/Desktop/Spam/pythonFile/numerical_Analysis/HW_3_2.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> ylist2 = [exact(x) for x in xlist2]
# ---> <a href='vscode-notebook-cell:/home/sarasadatnasr/Desktop/Spam/pythonFile/numerical_Analysis/HW_3_2.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> plot(xlist1, ylist1, xlist2, ylist2, 'blue', 'red', 'solid', 'solid', h1)
#
# ...

# %%
from termios import XCASE
from unittest.case import DIFF_OMITTED


def forward(function , h , x0):
    f_ah = function.subs(x,x0+h).evalf(PERCISION)
    f_a = function.subs(x,x0).evalf(PERCISION)
    return np.divide(np.subtract(f_ah,f_a),h)
def backward(function , h,x0):
    f_ah = function.subs(x,x0-h).evalf(PERCISION)
    f_a = function.subs(x,x0).evalf(PERCISION)
    return np.divide(np.subtract(f_a , f_ah),h)
def central(function , h , x0):
    f_aph = function.subs(x,x0+h).evalf(PERCISION)
    f_ash = function.subs(x,x0-h).evalf(PERCISION)
    return np.divide(np.subtract(f_aph , f_ash),np.multiply(2,h))
def diff_(function ,x0):
    derivate_function = DIFF_OMITTED(function)
    return derivate_function.subs(XCASE,x0).evalf(PERCISION)
# Out:
# 1.0301296918748948

# %%
for i in range (1,4):
    for j in x :
            y[i+1] = 2*y[i]-y[i-1] - ((0.25)*((y[]+y[0])/2*0.25)*((0.25)**2))- (y[1]*((0.25)**2)) + math.sqrt(1+0.25)
